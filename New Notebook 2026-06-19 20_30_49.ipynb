# %%
# %sql
SELECT *
FROM misgauravcatalog.retaildb.pipeline_watermarks;

pipeline_name,last_processed_version
bronze_to_silver,4

# %%
# %sql
DESCRIBE HISTORY misgauravcatalog.retaildb.orders_bronze;


version,timestamp,userId,userName,operation,operationParameters,job,notebook,queryHistoryStatementId,clusterId,readVersion,isolationLevel,isBlindAppend,operationMetrics,userMetadata,engineInfo
4,2026-06-19T14:57:46.920Z,218129261881966,gauravmishra010@gmail.com,COPY INTO,"{""statsOnLoad"":""true""}","{""jobId"":""1038254968223468"",""jobName"":""JOB via - GitHUb"",""jobRunId"":""424998100977965"",""runId"":""272072808994678"",""jobOwnerId"":""218129261881966"",""triggerType"":""manual""}","{""notebookId"":""4225947704022316""}",null,5619-145109-z6ea0z5s,3,WriteSerializable,true,"{""numFiles"":""1"",""numOutputRows"":""4"",""numOutputBytes"":""2295"",""numSkippedCorruptFiles"":""0""}",null,Databricks-Runtime/15.4.x-photon-scala2.12
3,2026-06-19T14:47:54.480Z,218129261881966,gauravmishra010@gmail.com,COPY INTO,"{""statsOnLoad"":""true""}","{""jobId"":""1038254968223468"",""jobName"":""JOB via - GitHUb"",""jobRunId"":""557713833706323"",""runId"":""385031407442375"",""jobOwnerId"":""218129261881966"",""triggerType"":""manual""}","{""notebookId"":""4225947704022316""}",null,5619-144109-826nq58g,2,WriteSerializable,true,"{""numFiles"":""3"",""numOutputRows"":""4"",""numOutputBytes"":""6618"",""numSkippedCorruptFiles"":""0""}",null,Databricks-Runtime/15.4.x-photon-scala2.12
2,2026-06-19T14:37:14.173Z,218129261881966,gauravmishra010@gmail.com,COPY INTO,"{""statsOnLoad"":""true""}","{""jobId"":""1038254968223468"",""jobName"":""JOB via - GitHUb"",""jobRunId"":""925073724355305"",""runId"":""1034640395238682"",""jobOwnerId"":""218129261881966"",""triggerType"":""manual""}","{""notebookId"":""4225947704022316""}",null,5619-143009-tpye562o,1,WriteSerializable,true,"{""numFiles"":""4"",""numOutputRows"":""4"",""numOutputBytes"":""8746"",""numSkippedCorruptFiles"":""0""}",null,Databricks-Runtime/15.4.x-photon-scala2.12
1,2026-06-19T14:21:56.748Z,218129261881966,gauravmishra010@gmail.com,COPY INTO,"{""statsOnLoad"":""true""}","{""jobId"":""1038254968223468"",""jobName"":""JOB via - GitHUb"",""jobRunId"":""517993591289889"",""runId"":""702436145222799"",""jobOwnerId"":""218129261881966"",""triggerType"":""manual""}","{""notebookId"":""4225947704022316""}",null,5619-141409-wklo308w,0,WriteSerializable,true,"{""numFiles"":""3"",""numOutputRows"":""4"",""numOutputBytes"":""6618"",""numSkippedCorruptFiles"":""0""}",null,Databricks-Runtime/15.4.x-photon-scala2.12
0,2026-06-19T14:20:15.367Z,218129261881966,gauravmishra010@gmail.com,CREATE TABLE,"{""partitionBy"":""[\""order_status\""]"",""clusterBy"":""[]"",""description"":null,""isManaged"":""false"",""properties"":""{\""delta.enableChangeDataFeed\"":\""true\"",\""delta.enableDeletionVectors\"":\""true\""}"",""statsOnLoad"":""false""}","{""jobId"":""1038254968223468"",""jobName"":""JOB via - GitHUb"",""jobRunId"":""517993591289889"",""runId"":""702436145222799"",""jobOwnerId"":""218129261881966"",""triggerType"":""manual""}","{""notebookId"":""4225947704022316""}",null,5619-141409-wklo308w,null,WriteSerializable,true,{},null,Databricks-Runtime/15.4.x-photon-scala2.12

# %%
# %sql
SELECT COUNT(*)
FROM misgauravcatalog.retaildb.orders_silver;
-- 9

# %%
# %sql
SELECT *
FROM misgauravcatalog.retaildb.orders_silver
ORDER BY order_id;

order_id,order_date,customer_id,order_status,order_year,order_month,createdon,modifiedon
1,2013-07-25,12111,CLOSED,2013,7,2026-06-19T14:22:36.377Z,2026-06-19T14:22:36.377Z
2,2013-07-25,12111,PENDING_PAYMENT,2013,7,2026-06-19T14:22:36.377Z,2026-06-19T14:22:36.377Z
3,2013-07-25,12111,CLOSED,2013,7,2026-06-19T14:37:52.860Z,2026-06-19T14:37:52.860Z
4,2013-07-25,12111,CLOSED,2013,7,2026-06-19T14:22:36.377Z,2026-06-19T14:22:36.377Z
5,2013-07-25,12111,CLOSED,2013,7,2026-06-19T14:48:35.900Z,2026-06-19T14:58:50.093Z
6,2013-07-25,12111,CLOSED,2013,7,2026-06-19T14:48:35.900Z,2026-06-19T14:58:50.093Z
7,2013-07-25,12111,CLOSED,2013,7,2026-06-19T14:58:50.093Z,2026-06-19T14:58:50.093Z
8,2013-07-25,12111,CLOSED,2013,7,2026-06-19T14:48:35.900Z,2026-06-19T14:58:50.093Z
11102,2013-07-25,12111,PENDING_PAYMENT,2013,7,2026-06-19T14:37:52.860Z,2026-06-19T14:37:52.860Z

# %%
# %sql
SELECT COUNT(*)
FROM misgauravcatalog.retaildb.orders_silver;
--9

# %%
# %sql
SELECT order_id, COUNT(*)
FROM misgauravcatalog.retaildb.orders_silver
GROUP BY order_id
HAVING COUNT(*) > 1;

order_id,COUNT(*) -- means 0 reocrds here

# %%
# %sql
DESCRIBE HISTORY misgauravcatalog.retaildb.orders_silver;

version,timestamp,userId,userName,operation,operationParameters,job,notebook,queryHistoryStatementId,clusterId,readVersion,isolationLevel,isBlindAppend,operationMetrics,userMetadata,engineInfo
7,2026-06-19T14:59:21.522Z,218129261881966,gauravmishra010@gmail.com,MERGE,"{""predicate"":""[\""(order_id#1526 = order_id#1479)\""]"",""matchedPredicates"":""[{\""actionType\"":\""update\""}]"",""statsOnLoad"":""false"",""notMatchedBySourcePredicates"":""[]"",""notMatchedPredicates"":""[{\""actionType\"":\""insert\""}]""}","{""jobId"":""1038254968223468"",""jobName"":""JOB via - GitHUb"",""jobRunId"":""424998100977965"",""runId"":""272072808994678"",""jobOwnerId"":""218129261881966"",""triggerType"":""manual""}","{""notebookId"":""4225947704022316""}",null,5619-145109-z6ea0z5s,6,WriteSerializable,false,"{""numTargetRowsCopied"":""0"",""numTargetRowsDeleted"":""0"",""numTargetBytesRemoved"":""4886"",""numTargetDeletionVectorsAdded"":""0"",""numTargetRowsMatchedUpdated"":""3"",""numTargetRowsMatchedDeleted"":""0"",""numTargetRowsUpdated"":""3"",""numTargetChangeFilesAdded"":""2"",""numTargetRowsNotMatchedBySourceDeleted"":""0"",""rewriteTimeMs"":""15704"",""numTargetFilesAdded"":""1"",""numTargetBytesAdded"":""2893"",""executionTimeMs"":""28053"",""materializeSourceTimeMs"":""5229"",""numTargetRowsInserted"":""1"",""numTargetDeletionVectorsUpdated"":""0"",""scanTimeMs"":""6579"",""numOutputRows"":""4"",""numTargetDeletionVectorsRemoved"":""0"",""numTargetRowsNotMatchedBySourceUpdated"":""0"",""numSourceRows"":""4"",""numTargetFilesRemoved"":""2""}",null,Databricks-Runtime/15.4.x-photon-scala2.12
6,2026-06-19T14:48:54.104Z,218129261881966,gauravmishra010@gmail.com,MERGE,"{""predicate"":""[\""(order_id#2234 = order_id#2187)\""]"",""matchedPredicates"":""[{\""actionType\"":\""update\""}]"",""statsOnLoad"":""false"",""notMatchedBySourcePredicates"":""[]"",""notMatchedPredicates"":""[{\""actionType\"":\""insert\""}]""}","{""jobId"":""1038254968223468"",""jobName"":""JOB via - GitHUb"",""jobRunId"":""557713833706323"",""runId"":""385031407442375"",""jobOwnerId"":""218129261881966"",""triggerType"":""manual""}","{""notebookId"":""4225947704022316""}",null,5619-144109-826nq58g,5,WriteSerializable,false,"{""numTargetRowsCopied"":""0"",""numTargetRowsDeleted"":""0"",""numTargetBytesRemoved"":""0"",""numTargetDeletionVectorsAdded"":""0"",""numTargetRowsMatchedUpdated"":""0"",""numTargetRowsMatchedDeleted"":""0"",""numTargetRowsUpdated"":""0"",""numTargetChangeFilesAdded"":""0"",""numTargetRowsNotMatchedBySourceDeleted"":""0"",""rewriteTimeMs"":""7510"",""numTargetFilesAdded"":""2"",""numTargetBytesAdded"":""4886"",""executionTimeMs"":""16117"",""materializeSourceTimeMs"":""5094"",""numTargetRowsInserted"":""3"",""numTargetDeletionVectorsUpdated"":""0"",""scanTimeMs"":""2989"",""numOutputRows"":""3"",""numTargetDeletionVectorsRemoved"":""0"",""numTargetRowsNotMatchedBySourceUpdated"":""0"",""numSourceRows"":""3"",""numTargetFilesRemoved"":""0""}",null,Databricks-Runtime/15.4.x-photon-scala2.12
5,2026-06-19T14:46:59.009Z,218129261881966,gauravmishra010@gmail.com,WRITE,"{""mode"":""Append"",""statsOnLoad"":""false"",""partitionBy"":""[]""}","{""jobId"":""1038254968223468"",""jobName"":""JOB via - GitHUb"",""jobRunId"":""557713833706323"",""runId"":""385031407442375"",""jobOwnerId"":""218129261881966"",""triggerType"":""manual""}","{""notebookId"":""4225947704022316""}",null,5619-144109-826nq58g,4,WriteSerializable,true,"{""numFiles"":""0"",""numOutputRows"":""0"",""numOutputBytes"":""0""}",null,Databricks-Runtime/15.4.x-photon-scala2.12
4,2026-06-19T14:38:10.402Z,218129261881966,gauravmishra010@gmail.com,MERGE,"{""predicate"":""[\""(order_id#2234 = order_id#2187)\""]"",""matchedPredicates"":""[{\""actionType\"":\""update\""}]"",""statsOnLoad"":""false"",""notMatchedBySourcePredicates"":""[]"",""notMatchedPredicates"":""[{\""actionType\"":\""insert\""}]""}","{""jobId"":""1038254968223468"",""jobName"":""JOB via - GitHUb"",""jobRunId"":""925073724355305"",""runId"":""1034640395238682"",""jobOwnerId"":""218129261881966"",""triggerType"":""manual""}","{""notebookId"":""4225947704022316""}",null,5619-143009-tpye562o,3,WriteSerializable,false,"{""numTargetRowsCopied"":""0"",""numTargetRowsDeleted"":""0"",""numTargetBytesRemoved"":""0"",""numTargetDeletionVectorsAdded"":""0"",""numTargetRowsMatchedUpdated"":""0"",""numTargetRowsMatchedDeleted"":""0"",""numTargetRowsUpdated"":""0"",""numTargetChangeFilesAdded"":""0"",""numTargetRowsNotMatchedBySourceDeleted"":""0"",""rewriteTimeMs"":""7009"",""numTargetFilesAdded"":""2"",""numTargetBytesAdded"":""4678"",""executionTimeMs"":""14984"",""materializeSourceTimeMs"":""4954"",""numTargetRowsInserted"":""2"",""numTargetDeletionVectorsUpdated"":""0"",""scanTimeMs"":""2631"",""numOutputRows"":""2"",""numTargetDeletionVectorsRemoved"":""0"",""numTargetRowsNotMatchedBySourceUpdated"":""0"",""numSourceRows"":""2"",""numTargetFilesRemoved"":""0""}",null,Databricks-Runtime/15.4.x-photon-scala2.12
3,2026-06-19T14:36:22.572Z,218129261881966,gauravmishra010@gmail.com,WRITE,"{""mode"":""Append"",""statsOnLoad"":""false"",""partitionBy"":""[]""}","{""jobId"":""1038254968223468"",""jobName"":""JOB via - GitHUb"",""jobRunId"":""925073724355305"",""runId"":""1034640395238682"",""jobOwnerId"":""218129261881966"",""triggerType"":""manual""}","{""notebookId"":""4225947704022316""}",null,5619-143009-tpye562o,2,WriteSerializable,true,"{""numFiles"":""0"",""numOutputRows"":""0"",""numOutputBytes"":""0""}",null,Databricks-Runtime/15.4.x-photon-scala2.12
2,2026-06-19T14:22:51.726Z,218129261881966,gauravmishra010@gmail.com,MERGE,"{""predicate"":""[\""(order_id#2267 = order_id#2231)\""]"",""matchedPredicates"":""[{\""actionType\"":\""update\""}]"",""statsOnLoad"":""false"",""notMatchedBySourcePredicates"":""[]"",""notMatchedPredicates"":""[{\""actionType\"":\""insert\""}]""}","{""jobId"":""1038254968223468"",""jobName"":""JOB via - GitHUb"",""jobRunId"":""517993591289889"",""runId"":""702436145222799"",""jobOwnerId"":""218129261881966"",""triggerType"":""manual""}","{""notebookId"":""4225947704022316""}",null,5619-141409-wklo308w,1,WriteSerializable,false,"{""numTargetRowsCopied"":""0"",""numTargetRowsDeleted"":""0"",""numTargetBytesRemoved"":""0"",""numTargetDeletionVectorsAdded"":""0"",""numTargetRowsMatchedUpdated"":""0"",""numTargetRowsMatchedDeleted"":""0"",""numTargetRowsUpdated"":""0"",""numTargetChangeFilesAdded"":""0"",""numTargetRowsNotMatchedBySourceDeleted"":""0"",""rewriteTimeMs"":""7179"",""numTargetFilesAdded"":""2"",""numTargetBytesAdded"":""4885"",""executionTimeMs"":""12370"",""materializeSourceTimeMs"":""2057"",""numTargetRowsInserted"":""3"",""numTargetDeletionVectorsUpdated"":""0"",""scanTimeMs"":""2362"",""numOutputRows"":""3"",""numTargetDeletionVectorsRemoved"":""0"",""numTargetRowsNotMatchedBySourceUpdated"":""0"",""numSourceRows"":""3"",""numTargetFilesRemoved"":""0""}",null,Databricks-Runtime/15.4.x-photon-scala2.12
1,2026-06-19T14:20:50.967Z,218129261881966,gauravmishra010@gmail.com,WRITE,"{""mode"":""Append"",""statsOnLoad"":""false"",""partitionBy"":""[]""}","{""jobId"":""1038254968223468"",""jobName"":""JOB via - GitHUb"",""jobRunId"":""517993591289889"",""runId"":""702436145222799"",""jobOwnerId"":""218129261881966"",""triggerType"":""manual""}","{""notebookId"":""4225947704022316""}",null,5619-141409-wklo308w,0,WriteSerializable,true,"{""numFiles"":""0"",""numOutputRows"":""0"",""numOutputBytes"":""0""}",null,Databricks-Runtime/15.4.x-photon-scala2.12
0,2026-06-19T14:20:30.996Z,218129261881966,gauravmishra010@gmail.com,CREATE TABLE,"{""partitionBy"":""[\""order_status\""]"",""clusterBy"":""[]"",""description"":null,""isManaged"":""false"",""properties"":""{\""delta.enableChangeDataFeed\"":\""true\"",\""delta.enableDeletionVectors\"":\""true\""}"",""statsOnLoad"":""false""}","{""jobId"":""1038254968223468"",""jobName"":""JOB via - GitHUb"",""jobRunId"":""517993591289889"",""runId"":""702436145222799"",""jobOwnerId"":""218129261881966"",""triggerType"":""manual""}","{""notebookId"":""4225947704022316""}",null,5619-141409-wklo308w,null,WriteSerializable,true,{},null,Databricks-Runtime/15.4.x-photon-scala2.12

# %%
# %sql
SELECT
    filename,
    COUNT(*)
FROM misgauravcatalog.retaildb.orders_bronze
GROUP BY filename
ORDER BY filename;

filename,COUNT(*)
gs://databricksfolder/raw/orders1.csv,4
gs://databricksfolder/raw/orders5.csv,4
gs://databricksfolder/raw/orders6.csv,4
gs://databricksfolder/raw/orders_update.csv,4
