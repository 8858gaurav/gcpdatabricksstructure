# %% [markdown]
# ran the pipeline for 5 input files: 1 by 1
# /Users/gauravmishra/Desktop/data/orders1.csv
# /Users/gauravmishra/Desktop/data/orders_update.csv
# /Users/gauravmishra/Desktop/data/orders5.csv
# /Users/gauravmishra/Desktop/data/orders6.csv

# %%
# orders1.csv
# order_id,order_date,customer_id,order_status
# 1,2013-07-25 00:00:00.0,12111,CLOSED
# 2,2013-07-25 00:00:00.0,12111,PENDING_PAYMENT
# 3,2013-07-25 00:00:00.0,12111,COMPLETE
# 4,2013-07-25 00:00:00.0,12111,CLOSED

# orders_update.csv
# order_id,order_date,customer_id,order_status
# 3,2013-07-25 00:00:00.0,12111,CLOSED
# 4,2013-07-25 00:00:00.0,12111,PENDING
# 11101,2013-07-25 00:00:00.0,12111,PROCESSING
# 11102,2013-07-25 00:00:00.0,12111,PENDING_PAYMENT

# orders5.csv
# order_id,order_date,customer_id,order_status
# 5,2013-07-25 00:00:00.0,12111,CLOSED
# 6,2013-07-25 00:00:00.0,12111,PENDING_PAYMENT
# 7,2013-07-25 00:00:00.0,12111,COMPLETE
# 8,2013-07-25 00:00:00.0,12111,CLOSED

# orders6.csv
# order_id,order_date,customer_id,order_status
# 5,2013-07-25 00:00:00.0,12111,CLOSED
# 6,2013-07-25 00:00:00.0,12111,CLOSED
# 7,2013-07-25 00:00:00.0,12111,CLOSED
# 8,2013-07-25 00:00:00.0,12111,CLOSED

# %%
# %sql
select * from misgauravcatalog.retaildb.orders_bronze;
order_id,order_date,customer_id,order_status,filename,createdon
-- 5,2013-07-25 00:00:00.0,12111,CLOSED,gs://databricksfolder/raw/orders6.csv,2026-06-19T15:46:54.222Z
-- 6,2013-07-25 00:00:00.0,12111,CLOSED,gs://databricksfolder/raw/orders6.csv,2026-06-19T15:46:54.222Z
-- 7,2013-07-25 00:00:00.0,12111,CLOSED,gs://databricksfolder/raw/orders6.csv,2026-06-19T15:46:54.222Z
-- 8,2013-07-25 00:00:00.0,12111,CLOSED,gs://databricksfolder/raw/orders6.csv,2026-06-19T15:46:54.222Z
-- 4,2013-07-25 00:00:00.0,12111,CLOSED,gs://databricksfolder/raw/orders1.csv,2026-06-19T15:20:28.735Z
-- 1,2013-07-25 00:00:00.0,12111,CLOSED,gs://databricksfolder/raw/orders1.csv,2026-06-19T15:20:28.735Z
-- 8,2013-07-25 00:00:00.0,12111,CLOSED,gs://databricksfolder/raw/orders5.csv,2026-06-19T15:35:57.289Z
-- 5,2013-07-25 00:00:00.0,12111,CLOSED,gs://databricksfolder/raw/orders5.csv,2026-06-19T15:35:57.289Z
-- 11102,2013-07-25 00:00:00.0,12111,PENDING_PAYMENT,gs://databricksfolder/raw/orders_update.csv,2026-06-19T15:25:59.535Z
-- 11101,2013-07-25 00:00:00.0,12111,PROCESSING,gs://databricksfolder/raw/orders_update.csv,2026-06-19T15:25:59.535Z
-- 2,2013-07-25 00:00:00.0,12111,PENDING_PAYMENT,gs://databricksfolder/raw/orders1.csv,2026-06-19T15:20:28.735Z
-- 6,2013-07-25 00:00:00.0,12111,PENDING_PAYMENT,gs://databricksfolder/raw/orders5.csv,2026-06-19T15:35:57.289Z
-- 4,2013-07-25 00:00:00.0,12111,PENDING,gs://databricksfolder/raw/orders_update.csv,2026-06-19T15:25:59.535Z
-- 3,2013-07-25 00:00:00.0,12111,CLOSED,gs://databricksfolder/raw/orders_update.csv,2026-06-19T15:25:59.535Z
-- 3,2013-07-25 00:00:00.0,12111,COMPLETE,gs://databricksfolder/raw/orders1.csv,2026-06-19T15:20:28.735Z
-- 7,2013-07-25 00:00:00.0,12111,COMPLETE,gs://databricksfolder/raw/orders5.csv,2026-06-19T15:35:57.289Z

# %%
# %sql
select * from misgauravcatalog.retaildb.orders_silver;
-- order_id,order_date,customer_id,order_status,order_year,order_month,createdon,modifiedon
-- 7,2013-07-25,12111,CLOSED,2013,7,2026-06-19T15:47:53.503Z,2026-06-19T15:47:53.503Z
-- 8,2013-07-25,12111,CLOSED,2013,7,2026-06-19T15:37:21.152Z,2026-06-19T15:47:53.503Z
-- 6,2013-07-25,12111,CLOSED,2013,7,2026-06-19T15:37:21.152Z,2026-06-19T15:47:53.503Z
-- 5,2013-07-25,12111,CLOSED,2013,7,2026-06-19T15:37:21.152Z,2026-06-19T15:47:53.503Z
-- 1,2013-07-25,12111,CLOSED,2013,7,2026-06-19T15:21:43.600Z,2026-06-19T15:21:43.600Z
-- 4,2013-07-25,12111,CLOSED,2013,7,2026-06-19T15:21:43.600Z,2026-06-19T15:21:43.600Z
-- 2,2013-07-25,12111,PENDING_PAYMENT,2013,7,2026-06-19T15:21:43.600Z,2026-06-19T15:21:43.600Z
-- 11102,2013-07-25,12111,PENDING_PAYMENT,2013,7,2026-06-19T15:27:20.911Z,2026-06-19T15:27:20.911Z
-- 3,2013-07-25,12111,CLOSED,2013,7,2026-06-19T15:27:20.911Z,2026-06-19T15:27:20.911Z

# %%
# %sql
select * from misgauravcatalog.retaildb.orders_gold;
-- customer_id,order_status,order_year,num_orders
-- 12111,CLOSED,2013,7
-- 12111,PENDING_PAYMENT,2013,2

# %%
# %sql
select * from misgauravcatalog.retaildb.pipeline_watermarks;
-- pipeline_name,last_processed_version
-- bronze_to_silver,4

# %%
# %sql
DESCRIBE HISTORY misgauravcatalog.retaildb.orders_bronze;
-- version,timestamp,userId,userName,operation,operationParameters,job,notebook,queryHistoryStatementId,clusterId,readVersion,isolationLevel,isBlindAppend,operationMetrics,userMetadata,engineInfo
-- 4,2026-06-19T15:47:08.140Z,218129261881966,gauravmishra010@gmail.com,COPY INTO,"{""statsOnLoad"":""true""}","{""jobId"":""1038254968223468"",""jobName"":""JOB via - GitHUb"",""jobRunId"":""952503250295901"",""runId"":""127832831658073"",""jobOwnerId"":""218129261881966"",""triggerType"":""manual""}","{""notebookId"":""4225947704022316""}",null,5619-154109-l5e541z4,3,WriteSerializable,true,"{""numFiles"":""1"",""numOutputRows"":""4"",""numOutputBytes"":""2295"",""numSkippedCorruptFiles"":""0""}",null,Databricks-Runtime/15.4.x-photon-scala2.12
-- 3,2026-06-19T15:36:22.164Z,218129261881966,gauravmishra010@gmail.com,COPY INTO,"{""statsOnLoad"":""true""}","{""jobId"":""1038254968223468"",""jobName"":""JOB via - GitHUb"",""jobRunId"":""526020026918912"",""runId"":""33482716199432"",""jobOwnerId"":""218129261881966"",""triggerType"":""manual""}","{""notebookId"":""4225947704022316""}",null,5619-153009-f2xdq6f4,2,WriteSerializable,true,"{""numFiles"":""3"",""numOutputRows"":""4"",""numOutputBytes"":""6615"",""numSkippedCorruptFiles"":""0""}",null,Databricks-Runtime/15.4.x-photon-scala2.12
-- 2,2026-06-19T15:26:27.746Z,218129261881966,gauravmishra010@gmail.com,COPY INTO,"{""statsOnLoad"":""true""}","{""jobId"":""1038254968223468"",""jobName"":""JOB via - GitHUb"",""jobRunId"":""928742516760841"",""runId"":""268484572056873"",""jobOwnerId"":""218129261881966"",""triggerType"":""manual""}","{""notebookId"":""4225947704022316""}",null,5619-152309-7xjsxbeo,1,WriteSerializable,true,"{""numFiles"":""4"",""numOutputRows"":""4"",""numOutputBytes"":""8742"",""numSkippedCorruptFiles"":""0""}",null,Databricks-Runtime/15.4.x-photon-scala2.12
-- 1,2026-06-19T15:20:53.674Z,218129261881966,gauravmishra010@gmail.com,COPY INTO,"{""statsOnLoad"":""true""}","{""jobId"":""1038254968223468"",""jobName"":""JOB via - GitHUb"",""jobRunId"":""121616398943536"",""runId"":""617797418670257"",""jobOwnerId"":""218129261881966"",""triggerType"":""manual""}","{""notebookId"":""4225947704022316""}",null,5619-151409-1wsu9xj4,0,WriteSerializable,true,"{""numFiles"":""3"",""numOutputRows"":""4"",""numOutputBytes"":""6618"",""numSkippedCorruptFiles"":""0""}",null,Databricks-Runtime/15.4.x-photon-scala2.12
-- 0,2026-06-19T15:11:50.123Z,218129261881966,gauravmishra010@gmail.com,CREATE TABLE,"{""partitionBy"":""[\""order_status\""]"",""clusterBy"":""[]"",""description"":null,""isManaged"":""false"",""properties"":""{\""delta.enableChangeDataFeed\"":\""true\"",\""delta.enableDeletionVectors\"":\""true\""}"",""statsOnLoad"":""false""}",null,"{""notebookId"":""486262812075188""}",b78f140d-4074-4dd7-aec5-e011a13d798d,0619-105050-9iz2gff8-v2n,null,WriteSerializable,true,{},null,Databricks-Runtime/18.2.x-photon-scala2.13

# %%
# %sql
DESCRIBE HISTORY misgauravcatalog.retaildb.orders_silver;
-- version,timestamp,userId,userName,operation,operationParameters,job,notebook,queryHistoryStatementId,clusterId,readVersion,isolationLevel,isBlindAppend,operationMetrics,userMetadata,engineInfo
-- 5,2026-06-19T15:48:15.025Z,218129261881966,gauravmishra010@gmail.com,MERGE,"{""predicate"":""[\""(order_id#1526 = order_id#1479)\""]"",""matchedPredicates"":""[{\""actionType\"":\""update\""}]"",""statsOnLoad"":""false"",""notMatchedBySourcePredicates"":""[]"",""notMatchedPredicates"":""[{\""actionType\"":\""insert\""}]""}","{""jobId"":""1038254968223468"",""jobName"":""JOB via - GitHUb"",""jobRunId"":""952503250295901"",""runId"":""127832831658073"",""jobOwnerId"":""218129261881966"",""triggerType"":""manual""}","{""notebookId"":""4225947704022316""}",null,5619-154109-l5e541z4,4,WriteSerializable,false,"{""numTargetRowsCopied"":""0"",""numTargetRowsDeleted"":""0"",""numTargetBytesRemoved"":""4884"",""numTargetDeletionVectorsAdded"":""0"",""numTargetRowsMatchedUpdated"":""3"",""numTargetRowsMatchedDeleted"":""0"",""numTargetRowsUpdated"":""3"",""numTargetChangeFilesAdded"":""2"",""numTargetRowsNotMatchedBySourceDeleted"":""0"",""rewriteTimeMs"":""11144"",""numTargetFilesAdded"":""1"",""numTargetBytesAdded"":""2893"",""executionTimeMs"":""19864"",""materializeSourceTimeMs"":""3205"",""numTargetRowsInserted"":""1"",""numTargetDeletionVectorsUpdated"":""0"",""scanTimeMs"":""5145"",""numOutputRows"":""4"",""numTargetDeletionVectorsRemoved"":""0"",""numTargetRowsNotMatchedBySourceUpdated"":""0"",""numSourceRows"":""4"",""numTargetFilesRemoved"":""2""}",null,Databricks-Runtime/15.4.x-photon-scala2.12
-- 4,2026-06-19T15:37:41.283Z,218129261881966,gauravmishra010@gmail.com,MERGE,"{""predicate"":""[\""(order_id#1526 = order_id#1479)\""]"",""matchedPredicates"":""[{\""actionType\"":\""update\""}]"",""statsOnLoad"":""false"",""notMatchedBySourcePredicates"":""[]"",""notMatchedPredicates"":""[{\""actionType\"":\""insert\""}]""}","{""jobId"":""1038254968223468"",""jobName"":""JOB via - GitHUb"",""jobRunId"":""526020026918912"",""runId"":""33482716199432"",""jobOwnerId"":""218129261881966"",""triggerType"":""manual""}","{""notebookId"":""4225947704022316""}",null,5619-153009-f2xdq6f4,3,WriteSerializable,false,"{""numTargetRowsCopied"":""0"",""numTargetRowsDeleted"":""0"",""numTargetBytesRemoved"":""0"",""numTargetDeletionVectorsAdded"":""0"",""numTargetRowsMatchedUpdated"":""0"",""numTargetRowsMatchedDeleted"":""0"",""numTargetRowsUpdated"":""0"",""numTargetChangeFilesAdded"":""0"",""numTargetRowsNotMatchedBySourceDeleted"":""0"",""rewriteTimeMs"":""8487"",""numTargetFilesAdded"":""2"",""numTargetBytesAdded"":""4884"",""executionTimeMs"":""18007"",""materializeSourceTimeMs"":""5037"",""numTargetRowsInserted"":""3"",""numTargetDeletionVectorsUpdated"":""0"",""scanTimeMs"":""3774"",""numOutputRows"":""3"",""numTargetDeletionVectorsRemoved"":""0"",""numTargetRowsNotMatchedBySourceUpdated"":""0"",""numSourceRows"":""3"",""numTargetFilesRemoved"":""0""}",null,Databricks-Runtime/15.4.x-photon-scala2.12
-- 3,2026-06-19T15:27:40.700Z,218129261881966,gauravmishra010@gmail.com,MERGE,"{""predicate"":""[\""(order_id#1526 = order_id#1479)\""]"",""matchedPredicates"":""[{\""actionType\"":\""update\""}]"",""statsOnLoad"":""false"",""notMatchedBySourcePredicates"":""[]"",""notMatchedPredicates"":""[{\""actionType\"":\""insert\""}]""}","{""jobId"":""1038254968223468"",""jobName"":""JOB via - GitHUb"",""jobRunId"":""928742516760841"",""runId"":""268484572056873"",""jobOwnerId"":""218129261881966"",""triggerType"":""manual""}","{""notebookId"":""4225947704022316""}",null,5619-152309-7xjsxbeo,2,WriteSerializable,false,"{""numTargetRowsCopied"":""0"",""numTargetRowsDeleted"":""0"",""numTargetBytesRemoved"":""0"",""numTargetDeletionVectorsAdded"":""0"",""numTargetRowsMatchedUpdated"":""0"",""numTargetRowsMatchedDeleted"":""0"",""numTargetRowsUpdated"":""0"",""numTargetChangeFilesAdded"":""0"",""numTargetRowsNotMatchedBySourceDeleted"":""0"",""rewriteTimeMs"":""8333"",""numTargetFilesAdded"":""2"",""numTargetBytesAdded"":""4676"",""executionTimeMs"":""16693"",""materializeSourceTimeMs"":""4840"",""numTargetRowsInserted"":""2"",""numTargetDeletionVectorsUpdated"":""0"",""scanTimeMs"":""2823"",""numOutputRows"":""2"",""numTargetDeletionVectorsRemoved"":""0"",""numTargetRowsNotMatchedBySourceUpdated"":""0"",""numSourceRows"":""2"",""numTargetFilesRemoved"":""0""}",null,Databricks-Runtime/15.4.x-photon-scala2.12
-- 2,2026-06-19T15:21:59.235Z,218129261881966,gauravmishra010@gmail.com,MERGE,"{""predicate"":""[\""(order_id#1521 = order_id#1485)\""]"",""matchedPredicates"":""[{\""actionType\"":\""update\""}]"",""statsOnLoad"":""false"",""notMatchedBySourcePredicates"":""[]"",""notMatchedPredicates"":""[{\""actionType\"":\""insert\""}]""}","{""jobId"":""1038254968223468"",""jobName"":""JOB via - GitHUb"",""jobRunId"":""121616398943536"",""runId"":""617797418670257"",""jobOwnerId"":""218129261881966"",""triggerType"":""manual""}","{""notebookId"":""4225947704022316""}",null,5619-151409-1wsu9xj4,1,WriteSerializable,false,"{""numTargetRowsCopied"":""0"",""numTargetRowsDeleted"":""0"",""numTargetBytesRemoved"":""0"",""numTargetDeletionVectorsAdded"":""0"",""numTargetRowsMatchedUpdated"":""0"",""numTargetRowsMatchedDeleted"":""0"",""numTargetRowsUpdated"":""0"",""numTargetChangeFilesAdded"":""0"",""numTargetRowsNotMatchedBySourceDeleted"":""0"",""rewriteTimeMs"":""7331"",""numTargetFilesAdded"":""2"",""numTargetBytesAdded"":""4885"",""executionTimeMs"":""12454"",""materializeSourceTimeMs"":""2155"",""numTargetRowsInserted"":""3"",""numTargetDeletionVectorsUpdated"":""0"",""scanTimeMs"":""2386"",""numOutputRows"":""3"",""numTargetDeletionVectorsRemoved"":""0"",""numTargetRowsNotMatchedBySourceUpdated"":""0"",""numSourceRows"":""3"",""numTargetFilesRemoved"":""0""}",null,Databricks-Runtime/15.4.x-photon-scala2.12
-- 1,2026-06-19T15:12:19.094Z,218129261881966,gauravmishra010@gmail.com,WRITE,"{""mode"":""Append"",""statsOnLoad"":""false"",""partitionBy"":""[]""}",null,"{""notebookId"":""486262812075188""}",406b602e-b1a2-472f-9486-07d6a456e033,0619-105050-9iz2gff8-v2n,0,WriteSerializable,true,"{""numFiles"":""0"",""numOutputRows"":""0"",""numOutputBytes"":""0""}",null,Databricks-Runtime/18.2.x-photon-scala2.13
-- 0,2026-06-19T15:12:00.873Z,218129261881966,gauravmishra010@gmail.com,CREATE TABLE,"{""partitionBy"":""[\""order_status\""]"",""clusterBy"":""[]"",""description"":null,""isManaged"":""false"",""properties"":""{\""delta.enableChangeDataFeed\"":\""true\"",\""delta.enableDeletionVectors\"":\""true\""}"",""statsOnLoad"":""false""}",null,"{""notebookId"":""486262812075188""}",655edfee-9a28-41a9-bd35-9333c2226c7f,0619-105050-9iz2gff8-v2n,null,WriteSerializable,true,{},null,Databricks-Runtime/18.2.x-photon-scala2.13
